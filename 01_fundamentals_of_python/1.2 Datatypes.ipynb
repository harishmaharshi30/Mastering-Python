# %% [markdown]
# ## Basic Datatypes in Python

# %% [markdown]
# **1) Defination:**
#    - Data types are a classification of data which tell the compiler or interpreter how the programmer intends to use the data.
#    - They Determine the type of operations that can be performed on the data, the values that the data can take,
#    - and the amount of money needed to store the data
#
# **3) Importance of Data types in programming**
#    - Data types ensure that data is stored in an efficient way.
#    - They help in performing correct operations on data.
#    - Proper use of data types can prevent errors and bugs in the program

# %% [markdown]
# ### Topics we can uderstand:

# %% [markdown]
# 1. Introduction to Data Types
# 2. Importance of Data types in Programming
# 3. **Basic Data Types**
#    - Integers
#    - Floating-point numbers
#    - Strings
#    - Booleans
# 4. **Advanced Data Types**
#    - Lists
#    - Tuples
#    - Sets
#    - Dictionaries
# 5. Type Conversions
# 6. Practical Exercises

# %%
## Integers  Exercises
age = 42
type(age)
# Out:
# int

# %%
## Floating point Data type
height = 5.11
print(height)
print(type(height))
# Out:
# 5.11
# <class 'float'>

# %%
## string datatype example
name = "Harish"
print(name)
print(type(name))
# Out:
# Harish
# <class 'str'>

# %%
## Boolean Datatype
is_true = True
print(type(is_true))
# Out:
# <class 'bool'>

# %%
True + True
# Out:
# 2

# %%
True + False
# Out:
# 1

# %%
False + False
# Out:
# 0

# %%
is_true = bool(False)
print(is_true)
# Out:
# False

# %%
is_true = bool(True)
print(is_true)
# Out:
# True

# %%
is_true = bool()   # Default value is False
print(is_true)
# Out:
# False

# %%
val1 = 4
val2=5
print(val1 == val2)
type(val1 == val2)
# Out:
# False
# bool

# %%
## Common errors when you are working
# sum = 'Harish' + 5    # TypeError: can only concatenate str (not "int") to str
# print(sum)

# %%
sum = "Harish" + str(5)
print(sum)
# Out:
# Harish5
